# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install h2o --user

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
import time

# %%
import h2o

# %%
# !ln -s /content/gdrive/My\ Drive/agio /agio

# %%
cd /agio
# Out:
# /content/gdrive/My Drive/agio

# %%
# !wget https://data.cityofnewyork.us/api/views/erm2-nwe9/rows.csv?accessType=DOWNLOAD

# %%
# !mv rows.csv\?accessType\=DOWNLOAD nyc_311_data.csv

# %%
# !ls
# Out:
#  311_SR_Data_Dictionary_2018.xlsx   nyc_311_data.csv
#  agio				    nyc_311_EDA.ipynb
#  nyc_311_2016.csv		    nyc_311_getData.ipynb
# 'nyc_311_>2016_samp.csv'	    nyc_raw_subset.csv

# %%
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "11.0.8" 2020-07-14; OpenJDK Runtime Environment (build 11.0.8+10-post-Ubuntu-0ubuntu118.04.1); OpenJDK 64-Bit Server VM (build 11.0.8+10-post-Ubuntu-0ubuntu118.04.1, mixed mode, sharing)
#   Starting server from /root/.local/lib/python3.6/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpbkg2nev2
#   JVM stdout: /tmp/tmpbkg2nev2/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpbkg2nev2/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ------------------------------------------------------------------
# H2O_cluster_uptime:         02 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.30.1.3
# ...

# %%
df = h2o.import_file('nyc_311_2016.csv')

# %%
df.shape

# %%
cols = df.columns
cols = [col.lower().replace(' ','_') for col in cols]

df.columns = cols

# %%
df.head()
# Out:
# <table>
# <thead>
# ...

# %%
df2016 = df[df['created_date'] >= datetime(2016,1,1)]

# %%
df2016.shape
# Out:
# (12175484, 41)

# %%
df2016.shape

# %%
h2o.export_file(df2016, 'nyc_311_2016.csv')
# Out:
# Export File progress: |███████████████████████████████████████████████████| 100%

# %%
df.types
# Out:
# {'address_type': 'enum',
#  'agency': 'enum',
#  'agency_name': 'enum',
#  'bbl': 'int',
#  'borough': 'enum',
#  'bridge_highway_direction': 'string',
#  'bridge_highway_name': 'string',
#  'bridge_highway_segment': 'string',
#  'city': 'enum',
#  'closed_date': 'time',
#  'community_board': 'enum',
#  'complaint_type': 'enum',
#  'created_date': 'time',
#  'cross_street_1': 'enum',
#  'cross_street_2': 'enum',
#  'descriptor': 'enum',
#  'due_date': 'time',
#  'facility_type': 'enum',
#  'incident_address': 'enum',
#  'incident_zip': 'int',
#  'intersection_street_1': 'enum',
#  'intersection_street_2': 'enum',
#  'landmark': 'string',
#  'latitude': 'real',
#  'location': 'enum',
#  'location_type': 'enum',
#  'longitude': 'real',
#  'open_data_channel_type': 'enum',
#  'park_borough': 'enum',
#  'park_facility_name': 'enum',
#  'resolution_action_updated_date': 'time',
#  'resolution_description': 'enum',
#  'road_ramp': 'enum',
#  'status': 'enum',
#  'street_name': 'enum',
# ...

# %%
df.shape
# Out:
# (24219783, 41)

# %%
# df['cnt'] = 1
# daily_totals = df[['created_date', 'cnt']].group_by(by='created_date').sum('cnt').get_frame()

# %%
# daily_totals.get_frame().shape

# %%
df2016 = df[df['created_date'] >= datetime(2016,1,1)]

# %%
# df2016['unique_key'].asfactor().nlevels()

# %%
df2016['unique_key'].min(), df2016['unique_key'].max()
# Out:
# (32305076.0, 47963722.0)

# %%
df2016['unique_key'].max() - df2016['unique_key'].min()
# Out:
# 15658646.0

# %%
df2016.shape
# Out:
# (12175484, 41)
